# %%
spark.sql("SHOW CATALOGS").show(truncate=False)
# Out:
# +---------+
# |catalog  |
# +---------+
# |samples  |
# |system   |
# |workspace|
# +---------+

# %%
spark.sql("SHOW SCHEMAS").show(truncate=False)
# Out:
# +------------------+
# |databaseName      |
# +------------------+
# |default           |
# |information_schema|
# +------------------+

# %%
spark.sql("SELECT current_catalog(), current_schema()").show()
# Out:
# +-----------------+----------------+
# |current_catalog()|current_schema()|
# +-----------------+----------------+
# |        workspace|         default|
# +-----------------+----------------+

# %%
spark.sql("SHOW SCHEMAS").show(truncate=False)
# Out:
# +------------------+
# |databaseName      |
# +------------------+
# |default           |
# |information_schema|
# +------------------+

# %%
spark.sql("CREATE SCHEMA pei_assignment")
# Out:
# DataFrame[]

# %%
spark.sql("USE SCHEMA pei_assignment")
# Out:
# DataFrame[]

# %%
spark.sql("SELECT current_catalog(), current_schema()").show()
# Out:
# +-----------------+----------------+
# |current_catalog()|current_schema()|
# +-----------------+----------------+
# |        workspace|  pei_assignment|
# +-----------------+----------------+
