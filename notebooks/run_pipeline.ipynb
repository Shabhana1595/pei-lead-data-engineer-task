# %%
# ============================================================
# Run Complete ETL Pipeline
# ============================================================

print("Starting Pipeline...")

# Bronze Layer
dbutils.notebook.run("01_raw_ingestion", 0)

# Silver Layer
dbutils.notebook.run("02_dimension_enrichment", 0)

# Silver Fact
dbutils.notebook.run("03_order_enrichment", 0)

# Gold Layer
dbutils.notebook.run("04_gold_aggregation", 0)

print("Pipeline completed successfully.")
# Out:
# Starting Pipeline...
# Pipeline completed successfully.
